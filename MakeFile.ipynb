# %%
# not this

# !pyinstaller -w BaseballVision.py --add-data \
"C:\Temp\Anaconda\Lib\site-packages\mediapipe\modules\pose_landmark\pose_landmark_cpu.binarypb;mediapipe/modules/pose_landmark" \
--add-data "C:\Temp\Anaconda\Lib\site-packages\mediapipe\modules\pose_landmark\pose_landmark_heavy.tflite;mediapipe/modules/pose_landmark"\
--add-data ".\_internal:."\
--hidden-import "mediapipe.python._framework_bindings" \
--hidden-import "mediapipe.python.solutions" \
--hidden-import "mediapipe.python.solutions.pose"
# Out:
# ^C

# %%
# !pyinstaller --collect-data mediapipe -w BaseballVision.py\
--add-data ".\_internal:."
# Out:
# 2906 INFO: PyInstaller: 6.14.2, contrib hooks: 2025.5
# 2906 INFO: Python: 3.11.7 (conda)
# 2912 INFO: Platform: Windows-10-10.0.26100-SP0
# 2912 INFO: Python environment: C:\Temp\Anaconda
# 2913 INFO: wrote C:\Users\이지헌\baseball\BaseballVision\BaseballVision.spec
# 4269 INFO: Module search paths (PYTHONPATH):
# ['C:\\Temp\\Anaconda\\Scripts\\pyinstaller.exe',
#  'C:\\Temp\\Anaconda\\python311.zip',
#  'C:\\Temp\\Anaconda\\DLLs',
#  'C:\\Temp\\Anaconda\\Lib',
#  'C:\\Temp\\Anaconda',
#  'C:\\Users\\이지헌\\AppData\\Roaming\\Python\\Python311\\site-packages',
#  'C:\\Temp\\Anaconda\\Lib\\site-packages',
#  'C:\\Temp\\Anaconda\\Lib\\site-packages\\win32',
#  'C:\\Temp\\Anaconda\\Lib\\site-packages\\win32\\lib',
#  'C:\\Temp\\Anaconda\\Lib\\site-packages\\Pythonwin',
#  'C:\\Users\\이지헌\\baseball\\BaseballVision']
# 6003 INFO: Appending 'datas' from .spec
# 6005 INFO: checking Analysis
# ...
